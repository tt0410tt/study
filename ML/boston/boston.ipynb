# %% [markdown]
# 보스턴 집값 데이터 셋 예측

# %%
# !pip install -q pandas # 엑셀파일 읽어주는 라이브러리
# Out:
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/setuptools-75.1.0-py3.12.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/setuptools-75.1.0-py3.12.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/setuptools-75.1.0-py3.12.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/setuptools-75.1.0-py3.12.egg-info due to invalid metadata entry 'name'

# %%
import numpy as np

# %%
import pandas as pd

# %%
boston_df = pd.read_csv('./boston.csv') #pandas 데이터 프레임을 불러옴.

# %%
boston_df #집값을 예측 (regression) why 연속적이니깐?
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# input과 output을 나눠줌 (input =medv를 제외한 나머지, output = medv) 13개는 입력으로 쓰고 1개는 출력으로 쓴다.

# %%
boston_df.drop(columns='MEDV')
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
x = boston_df.drop(columns='MEDV')

# %%
boston_df[['MEDV']]
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
y = boston_df[['MEDV']] #괄호 2개 주의 why? column일 경우 괄호를 2개를 침.

# %% [markdown]
# 데이터셋 분할 해줌

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# scikit-learn은 numpy와 pandas를 입력으로 받을 수 있는 라이브러리

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# 학습을 시킴, decsion tree regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)

# %%
y_test
# Out:
#      MEDV
# 220  26.7
# 439  12.8
# 57   31.6
# 483  21.8
# 309  20.3
# ..    ...
# 336  19.5
# 84   23.9
# 390  15.1
# 495  23.1
# 384   8.8
#
# [102 rows x 1 columns]

# %%
y_pred
# Out:
# array([31.6, 10.8, 30.1, 18.7, 21.6, 31.6, 25.1, 13. , 15. ,  8.3,  7.2,
#        23.2, 46.7, 22.8, 16.6, 15.6, 23.8, 23.1,  8.3, 20.4, 24.7, 18.6,
#        25. , 20.5, 13.9, 25.2, 20.6, 45.4, 11.7, 30.1, 19.6, 14.9, 22.5,
#        21.1, 32. , 15. , 18.2, 50. , 19.4, 34.6, 17.9, 16.3, 22.7, 21.2,
#         9.7, 21.9, 18.5, 30.8, 20.3, 17.4, 10.8, 22.8, 23.1, 12. , 50. ,
#        22.8, 21.1, 45.4, 22.2, 50. , 23.3, 21.1, 23.8, 30.5, 13.6, 22.9,
#        13.3, 28. , 26.6, 20.3, 14.8, 21.6, 23.3, 22.7, 14.1, 14.4, 20. ,
#        11.7, 21.4, 19.9, 38.7, 24.1, 14.1, 23.8, 41.7, 33.1, 50. , 27.1,
#        22.2, 12.6, 28.7, 19.6,  8.3, 24.8, 22.2, 11.7, 16.3, 18.5, 23.9,
#        11.7, 15.2, 10.2])

# %% [markdown]
# 성능 비교를 해야한다 무엇으로 성능 비교를 할까용? MSE(mean squred error)

# %% [markdown]
# 1. 수동으로 하는 방법 매우 복잡하고 어려움, 차원을 맞춰줘야함 왜냐하면 pandas 형식은 배열연산이 되지 않음 => numpy로 바꿔서 해야함

# %%
y_test_np = np.array(y_test)
y_pred_np = np.array(y_pred)

# %%
y_test_np.shape
# Out:
# (102, 1)

# %%
y_pred_np.shape
# Out:
# (102,)

# %%
y_test_np = np.array(y_test).ravel() # numpy 배열로 변환후에 1차원으로 변환
y_pred_np = np.array(y_pred)

# %%
y_test_np.shape
# Out:
# (102,)

# %%
y_pred_np.shape
# Out:
# (102,)

# %%
mse = np.sum((y_test_np - y_pred_np) ** 2) / len(y_test_np)

# %%
print("MSE:", mse)
# Out:
# MSE: 16.76901960784314

# %% [markdown]
# 2. 함수를 사용하는 방법

# %%
from sklearn.metrics import mean_squared_error

# %%
mse_dt = mean_squared_error(y_test, y_pred)
print(f"결정 트리 MSE: {mse_dt}")
# Out:
# 결정 트리 MSE: 16.76901960784314

# %% [markdown]
# 숙제1 : mse 뿐아니라 mae도 구현해서 성능을 측정해보자
# 힌트 : from sklearn.metrics import mean_absolute_error

# %%
import math
from sklearn.metrics import mean_absolute_error

# %%
#숙제1 : mse 뿐아니라 mae도 구현해서 성능을 측정해보자
# 힌트 : from sklearn.metrics import mean_absolute_error
# 1번 함수를 구현한다.
MAE= np.sum(np.absolute(y_pred_np-y_test_np))/len(y_pred_np)
print(MAE)
# Out:
# 2.8568627450980384

# %%
# 1-2 함수를 사용한다.
mean_absolute_error(y_pred=y_pred_np,y_true=y_test_np)
# Out:
# 2.8568627450980384

# %% [markdown]
# 숙제2 : svm regression과 decsion tree regression의 성능을 비교해보자
# 힌트 : from sklearn.svm import SVR

# %%
from sklearn.svm import SVR

# %%
model2 = SVR(kernel='linear')

# %%
model2.fit(x_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
Y_pred=model2.predict(x_test)

# %%
Mse_dt = mean_squared_error(y_test, Y_pred)
Y_pred_np = np.array(Y_pred)
Y_pred_np.shape
MAE_dt=mean_absolute_error(y_pred=Y_pred_np,y_true=y_test_np)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 4
#       2 Y_pred_np = np.array(Y_pred)
#       3 Y_pred_np.shape
# ----> 4 MAE_dt=mean_absolute_error(Y_pred=Y_pred_np,y_true=y_test_np)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
# --> 191 params = func_sig.bind(*args, **kwargs)
#     192 params.apply_defaults()
#     194 # ignore self/cls and positional/keyword markers
#
# File /opt/anaconda3/lib/python3.12/inspect.py:3267, in Signature.bind(self, *args, **kwargs)
#    3262 def bind(self, /, *args, **kwargs):
#    3263     """Get a BoundArguments object, that maps the passed `args`
#    3264     and `kwargs` to the function's signature.  Raises `TypeError`
#    3265     if the passed arguments can not be bound.
#    3266     """
# -> 3267     return self._bind(args, kwargs)
#
# File /opt/anaconda3/lib/python3.12/inspect.py:3235, in Signature._bind(self, args, kwargs, partial)
#    3228 except KeyError:
#    3229     # We have no value for this parameter.  It's fine though,
#    3230     # if it has a default value, or it is an '*args'-like
#    3231     # parameter, left alone by the processing of positional
#    3232     # arguments.
#    3233     if (not partial and param.kind != _VAR_POSITIONAL and
#    3234                                         param.default is _empty):
# -> 3235         raise TypeError('missing a required argument: {arg!r}'. \
#    3236                         format(arg=param_name)) from None
#    3238 else:
#    3239     arguments[param_name] = arg_val
#
# TypeError: missing a required argument: 'y_pred'
